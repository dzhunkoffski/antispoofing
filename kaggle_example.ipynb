# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf /kaggle/working/antispoofing

# %%
# !git clone 'repo url'

# %%
import os

os.environ['WANDB_API_KEY'] = 'wandb key'

# %%
# !pip install speechbrain

# %%
# !cd antispoofing; python train.py --config /kaggle/working/antispoofing/src/configs/rawnet2.json
